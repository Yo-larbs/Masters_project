# %% [markdown]
# # importing code

# %%
import pandas as pd
import matplotlib as plt
import os

# %% [markdown]
# going to read in csv from neo, contains raw data

# %%
HIV1_Vec=pd.read_csv('../inputs/HIV1_vector(in).csv')

# %%
cell_line_unique=pd.unique(HIV1_Vec['cell_line'])
cell_line_dic={}
for i in cell_line_unique:
    df=HIV1_Vec[HIV1_Vec['cell_line']==i]
    cell_line_dic[i]=df

# %%
cell_line_dic['TIXI_4']
# Out:
#             assay cell_line     batch     screen replicate   titre  \
# 1906  HIV1_vector    TIXI_4  batch_07  screen_02    rep_01  titre1
# 1907  HIV1_vector    TIXI_4  batch_07  screen_02    rep_01  titre2
# 1908  HIV1_vector    TIXI_4  batch_07  screen_02    rep_01  titre3
# 1909  HIV1_vector    TIXI_4  batch_07  screen_02    rep_01  titre4
# 1910  HIV1_vector    TIXI_4  batch_07  screen_02    rep_01  titre5
# 1953  HIV1_vector    TIXI_4  batch_07  screen_02    rep_02  titre1
# 1954  HIV1_vector    TIXI_4  batch_07  screen_02    rep_02  titre2
# 1955  HIV1_vector    TIXI_4  batch_07  screen_02    rep_02  titre3
# 1956  HIV1_vector    TIXI_4  batch_07  screen_02    rep_02  titre4
# 1957  HIV1_vector    TIXI_4  batch_07  screen_02    rep_02  titre5
# 1998  HIV1_vector    TIXI_4  batch_07  screen_03    rep_01  titre1
# 1999  HIV1_vector    TIXI_4  batch_07  screen_03    rep_01  titre2
# 2000  HIV1_vector    TIXI_4  batch_07  screen_03    rep_01  titre3
# ...
